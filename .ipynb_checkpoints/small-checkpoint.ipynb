# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
# %matplotlib inline

# %%
#PRZYGOTOWYWANIE DANYCH
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7d9549019f66> in <module>()
# ----> 1 data=pd.read_csv('bank.csv',sep=';')
#
# NameError: name 'pd' is not defined

# %%
data=pd.read_csv('bank.csv',sep=';')

# %%
#Replace yes , no to 0 and 1 values 

data.y.replace(('yes', 'no'), (1, 0), inplace=True)
data.default.replace(('yes', 'no'), (1, 0), inplace=True)
data.housing.replace(('yes', 'no'), (1, 0), inplace=True)
data.loan.replace(('yes', 'no'), (1, 0), inplace=True)

# %%
#Change labels 
labelEncoder = LabelEncoder() 
data[:,2]= labelEncoder.fit_transform(data[:,2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-1439f3c5502b> in <module>()
#       1 #Change labels
#       2 labelEncoder = LabelEncoder()
# ----> 3 data[:,2]= labelEncoder.fit_transform(data[:,2])
#
# C:\Users\Ola\AppData\Roaming\Python\Python36\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\Users\Ola\AppData\Roaming\Python\Python36\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\Users\Ola\AppData\Roaming\Python\Python36\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1838         """Return the cached item, item represents a label indexer."""
#    1839         cache = self._item_cache
# -> 1840         res = cache.get(item)
#    1841         if res is None:
#    1842             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'

# %%
#Replace unknown to NA
data.poutcome.replace(('unknown'), (np.NaN), inplace=True)

# %%
#Drop Nan
data = data.dropna(axis=0)

# %%
data
# Out:
#       age            job   marital  education  default  balance  housing  \
# 1      33       services   married  secondary        0     4789        1
# 2      35     management    single   tertiary        0     1350        1
# 5      35     management    single   tertiary        0      747        0
# 6      36  self-employed   married   tertiary        0      307        1
# 9      43       services   married    primary        0      -88        1
# 14     31    blue-collar   married  secondary        0      360        1
# 17     37         admin.    single   tertiary        0     2317        1
# 19     31       services   married  secondary        0      132        0
# 27     67        retired   married    unknown        0      696        0
# 38     33     management   married  secondary        0     3935        1
# 40     38     management    single   tertiary        0    11971        1
# 46     55    blue-collar   married    primary        0      145        0
# 49     61         admin.   married    unknown        0     4629        1
# 53     34     technician   married   tertiary        0     1539        1
# 65     51    blue-collar  divorced  secondary        0      203        1
# 70     37     management   married   tertiary        0        0        0
# 76     41    blue-collar  divorced  secondary        0      174        1
# 79     40     unemployed   married  secondary        0      219        1
# 83     52       services   married  secondary        0      657        0
# 97     30         admin.    single   tertiary        0      261        0
# 98     36    blue-collar  divorced  secondary        0     2843        0
# 101    38     management    single   tertiary        0      493        1
# 105    32     management    single   tertiary        0      574        1
# 110    21        student    single  secondary        0     2488        0
# 113    33    blue-collar    single  secondary        0       22        0
# 124    51     management    single   tertiary        1      -55        1
# 128    32    blue-collar    single  secondary        0      228        0
# 133    48         admin.   married    unknown        0        0        1
# 136    29         admin.    single  secondary        0      428        1
# 148    46         admin.   married  secondary        0      179        1
# ...   ...            ...       ...        ...      ...      ...      ...
# 4362   40     technician   married  secondary        0      697        0
# 4363   38    blue-collar    single  secondary        0    13156        1
# 4372     0   cellular   18   nov       266         1    167         2
# 4387     1   cellular   21   nov       252         1    168         4
# 4396     0   cellular    8   may       239         1    368         2
# 4397     0   cellular   18   may         7         7    367        25
# 4413     0   cellular   16   oct       622         1    182         1
# 4420     0   cellular   20   nov       215         6    188         2
# 4423     0   cellular   18   oct       310         1    804         1
# 4428     0   cellular    2   feb       212         1    249         2
# 4433     1   cellular   11   may       474         1    256         1
# 4434     0   cellular   29   jan       219         1    246         1
# 4435     0  telephone    5   may       475         4    166         2
# 4447     0   cellular    7   may      1516         2    353         2
# 4453     0   cellular   20   nov       340         1    183         2
# 4456     0   cellular    6   apr       610         2    138         1
# 4458     0   cellular   16   dec       314         1    195         1
# 4459     0   cellular   17   apr       508         1    315        11
# 4463     0   cellular   21   nov        58         1    122         4
# 4465     0   cellular   28   jun       297         4    144         4
# 4473     0   cellular   20   apr       137         1    272         2
# 4485     0   cellular   11   may       238         2    361         5
# 4488     0   cellular   30   jan       130         1      2         1
# 4489     0   cellular    5   aug       131         5    356         3
# 4492     1   cellular   16   apr       346         1    234         3
# 4504     1   cellular   13   may       951         3    370         4
# 4514     0   cellular   20   apr        45         4    153         1
# 4519     0   cellular    6   feb       129         4    211         3
# 4520     1   cellular    3   apr       345         2    249         7
#
#      poutcome  y
# 1     failure  0
# 2     failure  0
# 5     failure  0
# 6       other  0
# 9     failure  0
# 14    failure  0
# 17    failure  0
# 19      other  0
# 27    failure  0
# 38    failure  1
# 40    failure  0
# 46      other  0
# 49    success  1
# 53      other  1
# 65    failure  0
# 70    success  1
# 76      other  0
# 79    failure  0
# 83    failure  1
# 97    failure  0
# 98    success  0
# 101   failure  0
# 105   failure  0
# 110   success  1
# 113   failure  0
# 124   failure  0
# 128   failure  0
# 133   failure  0
# 136   failure  0
# 148     other  0
# ...       ... ..
# 4362    other  0
# 4363  failure  0
# 4368    other  0
# 4372  failure  0
# 4387  failure  0
# 4396  failure  0
# 4397  failure  0
# 4413  failure  0
# 4420  failure  0
# 4423  failure  1
# 4428    other  0
# 4433  success  1
# 4434  failure  0
# 4435  failure  0
# 4447    other  1
# 4453  failure  0
# 4456  failure  0
# 4458  success  1
# 4459  success  0
# 4463  failure  0
# 4465    other  1
# 4473  failure  0
# 4485  failure  0
# 4488    other  0
# 4489  failure  0
# 4492  failure  0
# 4504  failure  1
# 4514  failure  0
# 4519    other  0
# 4520    other  0
#
# [816 rows x 17 columns]

# %%
print('Null values: ', data.isnull().values.any())
print('There are no null values')
# Out:
# Null values:  False
# There are no null values

# %%
print('Data shape: ',data.shape, '\nColumn types:\n',
data.dtypes)
# Out:
# Data shape:  (816, 17)
# Column types:
#  age           int64
# job          object
# marital      object
# education    object
# default       int64
# balance       int64
# housing       int64
# loan          int64
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y             int64
# dtype: object

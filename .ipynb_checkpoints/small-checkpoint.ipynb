# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import LabelEncoder
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
from sklearn.preprocessing import LabelEncoder , OneHotEncoder , StandardScaler
from sklearn.cross_validation import train_test_split
# %matplotlib inline

# %%
# I     PRZYGOTOWYWANIE DANYCH
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7d9549019f66> in <module>()
# ----> 1 data=pd.read_csv('bank.csv',sep=';')
#
# NameError: name 'pd' is not defined

# %%
data= pd.read_csv('bank.csv',sep=';')

# %%
#Replace unknown to NA
data.poutcome.replace(('unknown'), (np.NaN), inplace=True)
data.marital.replace(('other'), (np.NaN), inplace=True)
data.poutcome.replace(('other'), (np.NaN), inplace=True)
data.job.replace(('other'), (np.NaN), inplace=True)
# Out:
# C:\Users\Ola\AppData\Roaming\Python\Python36\site-packages\pandas\core\generic.py:4619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
#Drop Nan
data = data.dropna(axis=0)

# %%
#Take all of the independent variables 
X = data.iloc[:,:-1].values

# %%
Y = data.iloc[:,16].values

# %%
#Change labels 
labelEncoder_X = LabelEncoder() 
X[:,1]= labelEncoder_X.fit_transform(X[:,1])
onehotencoder = OneHotEncoder(categorical_features = [1])
X = onehotencoder.fit_transform(X).toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-391b7831a8d3> in <module>()
#       3 X[:,1]= labelEncoder_X.fit_transform(X[:,1])
#       4 onehotencoder = OneHotEncoder(categorical_features = [1])
# ----> 5 X = onehotencoder.fit_transform(X).toarray()
#       6
#       7 X["job_encoded"] = labelEncoder_X.fit_transform(X["job"])
#
# C:\Users\Ola\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\preprocessing\data.py in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# C:\Users\Ola\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\preprocessing\data.py in _transform_selected(X, transform, selected, copy)
#    1807     X : array or sparse matrix, shape=(n_samples, n_features_new)
#    1808     """
# -> 1809     X = check_array(X, accept_sparse='csc', copy=copy, dtype=FLOAT_DTYPES)
#    1810
#    1811     if isinstance(selected, six.string_types) and selected == "all":
#
# C:\Users\Ola\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'other'

# %%
labelEncoder_X = LabelEncoder() 
X[:,4]= labelEncoder_X.fit_transform(X[:,4])

# %%
#Change labels 
labelEncoder_Y = LabelEncoder() 
Y = labelEncoder_Y.fit_transform(Y)

# %%
#Replace yes , no to 0 and 1 values 

data.default.replace(('yes', 'no'), (1, 0), inplace=True)
data.housing.replace(('yes', 'no'), (1, 0), inplace=True)
data.loan.replace(('yes', 'no'), (1, 0), inplace=True)
data.poutcome.replace(('success', 'failure'), (1, 0), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-a1dec243663c> in <module>()
#       1 #Replace yes , no to 0 and 1 values
#       2
# ----> 3 data.default.replace(('yes', 'no'), (1, 0), inplace=True)
#       4 data.housing.replace(('yes', 'no'), (1, 0), inplace=True)
#       5 data.loan.replace(('yes', 'no'), (1, 0), inplace=True)
#
# C:\Users\Ola\AppData\Roaming\Python\Python36\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    4578                                                        dest_list=value,
#    4579                                                        inplace=inplace,
# -> 4580                                                        regex=regex)
#    4581
#    4582                 else:  # [NA, ''] -> 0
#
# C:\Users\Ola\AppData\Roaming\Python\Python36\site-packages\pandas\core\internals.py in replace_list(self, src_list, dest_list, inplace, regex, mgr)
#    3485             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3486
# -> 3487         masks = [comp(s) for i, s in enumerate(src_list)]
#    3488
#    3489         result_blocks = []
#
# C:\Users\Ola\AppData\Roaming\Python\Python36\site-packages\pandas\core\internals.py in <listcomp>(.0)
#    3485             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3486
# -> 3487         masks = [comp(s) for i, s in enumerate(src_list)]
#    3488
#    3489         result_blocks = []
#
# C:\Users\Ola\AppData\Roaming\Python\Python36\site-packages\pandas\core\internals.py in comp(s)
#    3483             if isna(s):
#    3484                 return isna(values)
# -> 3485             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3486
#    3487         masks = [comp(s) for i, s in enumerate(src_list)]
#
# C:\Users\Ola\AppData\Roaming\Python\Python36\site-packages\pandas\core\internals.py in _maybe_compare(a, b, op)
#    4945             type_names[1] = 'ndarray(dtype=%s)' % b.dtype
#    4946
# -> 4947         raise TypeError("Cannot compare types %r and %r" % tuple(type_names))
#    4948     return result
#    4949
#
# TypeError: Cannot compare types 'ndarray(dtype=int64)' and 'str'

# %%
print('Null values: ', data.isnull().values.any())
print('There are no null values')
# Out:
# Null values:  False
# There are no null values

# %%
#   II     Spliting dataset into test set and training set 
X_train , X_test , Y_train , Y_test = train_test_split(X , Y , test_size=0.3 , random_state = 0)

# %%
# III SCALING NUMERICAL VARIABLES 
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test = sc_X.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-136-73a66b61aa75> in <module>()
#       1 # III SCALING NUMERICAL VARIABLES
#       2 sc_X = StandardScaler()
# ----> 3 X_train = sc_X.fit_transform(X_train)
#       4 X_test = sc_X.transform(X_test)
#
# C:\Users\Ola\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     515         if y is None:
#     516             # fit method of arity 1 (unsupervised transformation)
# --> 517             return self.fit(X, **fit_params).transform(X)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
#
# C:\Users\Ola\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     588         # Reset internal state before fitting
#     589         self._reset()
# --> 590         return self.partial_fit(X, y)
#     591
#     592     def partial_fit(self, X, y=None):
#
# C:\Users\Ola\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     610         """
#     611         X = check_array(X, accept_sparse=('csr', 'csc'), copy=self.copy,
# --> 612                         warn_on_dtype=True, estimator=self, dtype=FLOAT_DTYPES)
#     613
#     614         # Even in the case of `with_mean=False`, we update the mean anyway
#
# C:\Users\Ola\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'failure'

# %%
#    IV   DISCRIPTIVE STATISTICS
print('Data shape: ',data.shape, '\nColumn types:\n',
data.dtypes)
# Out:
# Data shape:  (619, 17)
# Column types:
#  age           int64
# job          object
# marital      object
# education    object
# default       int64
# balance       int64
# housing       int64
# loan          int64
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y             int64
# dtype: object

# %%
data
# Out:
#       age          job   marital  education  default  balance  housing  loan  \
# 1      33     services   married  secondary        0     4789        1     1
# 2      35   management    single   tertiary        0     1350        1     0
# 5      35   management    single   tertiary        0      747        0     0
# 9      43     services   married    primary        0      -88        1     1
# 14     31  blue-collar   married  secondary        0      360        1     1
# 17     37       admin.    single   tertiary        0     2317        1     0
# 27     67      retired   married    unknown        0      696        0     0
# 38     33   management   married  secondary        0     3935        1     0
# 40     38   management    single   tertiary        0    11971        1     0
# 49     61       admin.   married    unknown        0     4629        1     0
# 65     51  blue-collar  divorced  secondary        0      203        1     0
# 70     37   management   married   tertiary        0        0        0     0
# 79     40   unemployed   married  secondary        0      219        1     0
# 83     52     services   married  secondary        0      657        0     0
# 97     30       admin.    single   tertiary        0      261        0     0
# 98     36  blue-collar  divorced  secondary        0     2843        0     0
# 101    38   management    single   tertiary        0      493        1     0
# 105    32   management    single   tertiary        0      574        1     0
# 110    21      student    single  secondary        0     2488        0     0
# 113    33  blue-collar    single  secondary        0       22        0     0
# 124    51   management    single   tertiary        1      -55        1     0
# 128    32  blue-collar    single  secondary        0      228        0     0
# 133    48       admin.   married    unknown        0        0        1     0
# 136    29       admin.    single  secondary        0      428        1     1
# 156    55       admin.   married  secondary        0      602        0     0
# 157    55   technician   married  secondary        0      273        1     0
# 164    28   management    single   tertiary        0       80        0     0
# 177    37       admin.   married  secondary        0      176        1     0
# 179    37       admin.   married   tertiary        0        0        1     0
# 186    34       admin.   married   tertiary        0      899        1     0
# ...   ...          ...       ...        ...      ...      ...      ...   ...
# 4312   30     services    single  secondary        0       20        1     0
# 4314   31   technician    single  secondary        0     1626        0     0
# 4319   70      retired  divorced  secondary        0     6850        0     0
# 4323   83      retired  divorced    primary        0        0        0     0
# 4324   50   management  divorced   tertiary        0      100        1     1
# 4337   73      retired   married    unknown        0      519        0     0
# 4343   51  blue-collar   married    primary        0       40        1     0
# 4347   32       admin.   married  secondary        0        0        1     1
# 4363   38  blue-collar    single  secondary        0    13156        1     0
# 4372   30   technician    single  secondary        0     4787        1     0
# 4387   31  blue-collar   married  secondary        0     3653        1     1
# 4396   41      retired    single    primary        0        0        0     0
# 4397   35  blue-collar   married  secondary        0      305        1     0
# 4413   65      retired   married    primary        0      493        0     0
# 4420   45   technician   married  secondary        0      999        1     0
# 4423   45   management    single   tertiary        0     2048        1     0
# 4433   40   management   married   tertiary        0      -17        1     1
# 4434   35   technician    single  secondary        0      175        1     0
# 4435   31   technician    single  secondary        0     4888        1     0
# 4453   35  blue-collar   married  secondary        0     5304        1     0
# 4456   37   management   married    primary        0     3953        1     0
# 4458   29   management    single   tertiary        0      572        0     0
# 4459   31       admin.    single  secondary        0      223        1     0
# 4463   33   technician    single  secondary        0      920        1     0
# 4473   33   technician   married  secondary        0     4790        1     0
# 4485   53  blue-collar   married    primary        0      238        1     0
# 4489   45   management   married   tertiary        0     6945        0     0
# 4492   32   technician    single  secondary        0      309        1     1
